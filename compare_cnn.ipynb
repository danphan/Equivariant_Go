# %%
from dlgo.data.parallel_processor import GoDataProcessor
from dlgo.encoders.oneplane import OnePlaneEncoder

from dlgo.networks import small
from tensorflow.keras import Sequential, Input, Model
from tensorflow.keras.layers import Dense, Layer, ZeroPadding2D, Conv2D, Softmax, Activation
from tensorflow.keras.layers import Concatenate, Conv2DTranspose, BatchNormalization, add
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.experimental.numpy import moveaxis


from tensorflow.keras.layers import Flatten
from p4conv_slow import P4Conv2D, P4MaxPooling2D

# %%
"""
Change Channels First to channels Last
"""
class Flip(Layer):
    def __init__(self):
        super(Flip,self).__init__(name='flip')
    def call(self,input_tensor):
        return moveaxis(input_tensor, [1,2,3],[3,1,2])

# %%
go_board_rows, go_board_cols = 19, 19
num_classes = go_board_rows * go_board_cols
num_games = 100

encoder = OnePlaneEncoder((go_board_rows, go_board_cols))

#to loop through zip files and create features/labels for training
processor = GoDataProcessor(encoder=encoder.name())

#create generator to loop through training/testing data
generator = processor.load_go_data('train', num_games, use_generator=True)
test_generator = processor.load_go_data('test',num_games, use_generator= True)
print(generator.get_num_samples(),'moves in one epoch')
print(generator.get_num_samples()/128,'steps per epoch')
# Out:
# >>> Reading cached index page
# KGS-2019_04-19-1255-.tar.gz 1255
# KGS-2019_03-19-1478-.tar.gz 1478
# KGS-2019_02-19-1412-.tar.gz 1412
# KGS-2019_01-19-2095-.tar.gz 2095
# KGS-2018_12-19-1992-.tar.gz 1992
# KGS-2018_11-19-1879-.tar.gz 1879
# KGS-2018_10-19-1209-.tar.gz 1209
# KGS-2018_09-19-1587-.tar.gz 1587
# KGS-2018_08-19-1447-.tar.gz 1447
# KGS-2018_07-19-949-.tar.gz 949
# KGS-2018_06-19-1002-.tar.gz 1002
# KGS-2018_05-19-1590-.tar.gz 1590
# KGS-2018_04-19-1612-.tar.gz 1612
# KGS-2018_03-19-833-.tar.gz 833
# KGS-2018_02-19-1167-.tar.gz 1167
# KGS-2018_01-19-1526-.tar.gz 1526
# KGS-2017_12-19-1488-.tar.gz 1488
# KGS-2017_11-19-945-.tar.gz 945
# KGS-2017_10-19-1351-.tar.gz 1351
# KGS-2017_09-19-1353-.tar.gz 1353
# KGS-2017_08-19-2205-.tar.gz 2205
# KGS-2017_07-19-1191-.tar.gz 1191
# KGS-2017_06-19-910-.tar.gz 910
# KGS-2017_05-19-847-.tar.gz 847
# KGS-2017_04-19-913-.tar.gz 913
# KGS-2017_03-19-717-.tar.gz 717
# KGS-2017_02-19-525-.tar.gz 525
# KGS-2017_01-19-733-.tar.gz 733
# KGS-2016_12-19-1208-.tar.gz 1208
# KGS-2016_11-19-980-.tar.gz 980
# KGS-2016_10-19-925-.tar.gz 925
# KGS-2016_09-19-1170-.tar.gz 1170
# KGS-2016_08-19-1374-.tar.gz 1374
# KGS-2016_07-19-1432-.tar.gz 1432
# KGS-2016_06-19-1540-.tar.gz 1540
# KGS-2016_05-19-1011-.tar.gz 1011
# KGS-2016_04-19-1081-.tar.gz 1081
# KGS-2016_03-19-895-.tar.gz 895
# KGS-2016_02-19-577-.tar.gz 577
# KGS-2016_01-19-756-.tar.gz 756
# KGS-2015-19-8133-.tar.gz 8133
# KGS-2014-19-13029-.tar.gz 13029
# KGS-2013-19-13783-.tar.gz 13783
# KGS-2012-19-13665-.tar.gz 13665
# KGS-2011-19-19099-.tar.gz 19099
# KGS-2010-19-17536-.tar.gz 17536
# KGS-2009-19-18837-.tar.gz 18837
# KGS-2008-19-14002-.tar.gz 14002
# KGS-2007-19-11644-.tar.gz 11644
# KGS-2006-19-10388-.tar.gz 10388
# KGS-2005-19-13941-.tar.gz 13941
# KGS-2004-19-12106-.tar.gz 12106
# KGS-2003-19-7582-.tar.gz 7582
# KGS-2002-19-3646-.tar.gz 3646
# KGS-2001-19-2298-.tar.gz 2298
# >>> Reading cached index page
# KGS-2019_04-19-1255-.tar.gz 1255
# KGS-2019_03-19-1478-.tar.gz 1478
# KGS-2019_02-19-1412-.tar.gz 1412
# KGS-2019_01-19-2095-.tar.gz 2095
# KGS-2018_12-19-1992-.tar.gz 1992
# KGS-2018_11-19-1879-.tar.gz 1879
# KGS-2018_10-19-1209-.tar.gz 1209
# KGS-2018_09-19-1587-.tar.gz 1587
# KGS-2018_08-19-1447-.tar.gz 1447
# KGS-2018_07-19-949-.tar.gz 949
# KGS-2018_06-19-1002-.tar.gz 1002
# KGS-2018_05-19-1590-.tar.gz 1590
# KGS-2018_04-19-1612-.tar.gz 1612
# KGS-2018_03-19-833-.tar.gz 833
# KGS-2018_02-19-1167-.tar.gz 1167
# KGS-2018_01-19-1526-.tar.gz 1526
# KGS-2017_12-19-1488-.tar.gz 1488
# KGS-2017_11-19-945-.tar.gz 945
# KGS-2017_10-19-1351-.tar.gz 1351
# KGS-2017_09-19-1353-.tar.gz 1353
# KGS-2017_08-19-2205-.tar.gz 2205
# KGS-2017_07-19-1191-.tar.gz 1191
# KGS-2017_06-19-910-.tar.gz 910
# KGS-2017_05-19-847-.tar.gz 847
# KGS-2017_04-19-913-.tar.gz 913
# KGS-2017_03-19-717-.tar.gz 717
# KGS-2017_02-19-525-.tar.gz 525
# KGS-2017_01-19-733-.tar.gz 733
# KGS-2016_12-19-1208-.tar.gz 1208
# KGS-2016_11-19-980-.tar.gz 980
# KGS-2016_10-19-925-.tar.gz 925
# KGS-2016_09-19-1170-.tar.gz 1170
# KGS-2016_08-19-1374-.tar.gz 1374
# KGS-2016_07-19-1432-.tar.gz 1432
# KGS-2016_06-19-1540-.tar.gz 1540
# KGS-2016_05-19-1011-.tar.gz 1011
# KGS-2016_04-19-1081-.tar.gz 1081
# KGS-2016_03-19-895-.tar.gz 895
# KGS-2016_02-19-577-.tar.gz 577
# KGS-2016_01-19-756-.tar.gz 756
# KGS-2015-19-8133-.tar.gz 8133
# KGS-2014-19-13029-.tar.gz 13029
# KGS-2013-19-13783-.tar.gz 13783
# KGS-2012-19-13665-.tar.gz 13665
# KGS-2011-19-19099-.tar.gz 19099
# KGS-2010-19-17536-.tar.gz 17536
# KGS-2009-19-18837-.tar.gz 18837
# KGS-2008-19-14002-.tar.gz 14002
# KGS-2007-19-11644-.tar.gz 11644
# KGS-2006-19-10388-.tar.gz 10388
# KGS-2005-19-13941-.tar.gz 13941
# KGS-2004-19-12106-.tar.gz 12106
# KGS-2003-19-7582-.tar.gz 7582
# KGS-2002-19-3646-.tar.gz 3646
# KGS-2001-19-2298-.tar.gz 2298
# total num training games available: 179689
# Drawn 100 training sample games:
# >>> Reading cached index page
# KGS-2019_04-19-1255-.tar.gz 1255
# KGS-2019_03-19-1478-.tar.gz 1478
# KGS-2019_02-19-1412-.tar.gz 1412
# KGS-2019_01-19-2095-.tar.gz 2095
# KGS-2018_12-19-1992-.tar.gz 1992
# KGS-2018_11-19-1879-.tar.gz 1879
# KGS-2018_10-19-1209-.tar.gz 1209
# KGS-2018_09-19-1587-.tar.gz 1587
# KGS-2018_08-19-1447-.tar.gz 1447
# KGS-2018_07-19-949-.tar.gz 949
# KGS-2018_06-19-1002-.tar.gz 1002
# KGS-2018_05-19-1590-.tar.gz 1590
# KGS-2018_04-19-1612-.tar.gz 1612
# KGS-2018_03-19-833-.tar.gz 833
# KGS-2018_02-19-1167-.tar.gz 1167
# KGS-2018_01-19-1526-.tar.gz 1526
# KGS-2017_12-19-1488-.tar.gz 1488
# KGS-2017_11-19-945-.tar.gz 945
# KGS-2017_10-19-1351-.tar.gz 1351
# KGS-2017_09-19-1353-.tar.gz 1353
# KGS-2017_08-19-2205-.tar.gz 2205
# KGS-2017_07-19-1191-.tar.gz 1191
# KGS-2017_06-19-910-.tar.gz 910
# KGS-2017_05-19-847-.tar.gz 847
# KGS-2017_04-19-913-.tar.gz 913
# KGS-2017_03-19-717-.tar.gz 717
# KGS-2017_02-19-525-.tar.gz 525
# KGS-2017_01-19-733-.tar.gz 733
# KGS-2016_12-19-1208-.tar.gz 1208
# KGS-2016_11-19-980-.tar.gz 980
# KGS-2016_10-19-925-.tar.gz 925
# KGS-2016_09-19-1170-.tar.gz 1170
# KGS-2016_08-19-1374-.tar.gz 1374
# KGS-2016_07-19-1432-.tar.gz 1432
# KGS-2016_06-19-1540-.tar.gz 1540
# KGS-2016_05-19-1011-.tar.gz 1011
# KGS-2016_04-19-1081-.tar.gz 1081
# KGS-2016_03-19-895-.tar.gz 895
# KGS-2016_02-19-577-.tar.gz 577
# KGS-2016_01-19-756-.tar.gz 756
# KGS-2015-19-8133-.tar.gz 8133
# KGS-2014-19-13029-.tar.gz 13029
# KGS-2013-19-13783-.tar.gz 13783
# KGS-2012-19-13665-.tar.gz 13665
# KGS-2011-19-19099-.tar.gz 19099
# KGS-2010-19-17536-.tar.gz 17536
# KGS-2009-19-18837-.tar.gz 18837
# KGS-2008-19-14002-.tar.gz 14002
# KGS-2007-19-11644-.tar.gz 11644
# KGS-2006-19-10388-.tar.gz 10388
# KGS-2005-19-13941-.tar.gz 13941
# KGS-2004-19-12106-.tar.gz 12106
# KGS-2003-19-7582-.tar.gz 7582
# KGS-2002-19-3646-.tar.gz 3646
# KGS-2001-19-2298-.tar.gz 2298
# 42112 moves in one epoch
# 329.0 steps per epoch

# %% [markdown]
# ## Fully-Convolutional VGG-type CNN

# %%
#define keras model
input_shape = (encoder.num_planes, go_board_rows, go_board_cols)

model = Sequential()
model.add(Input(shape=input_shape))
model.add(Flip())

#three 3x3 convs has a receptive field equivalent to one 7x7
model.add(Conv2D(filters = 16, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(Conv2D(filters = 16, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(Conv2D(filters = 32, kernel_size = (3, 3),activation='relu',padding = 'same'))


#two 3x3 convs has a receptive field equivalent to one 5x5
model.add(Conv2D(filters = 32, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(Conv2D(filters = 50, kernel_size = (3, 3),activation='relu',padding = 'same'))


model.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu',padding='same'))

#obtain prediction
model.add(Conv2D(filters = 1, kernel_size = (1,1), activation = 'relu'))

model.add(Flatten())
model.add(Softmax())

#model.add(Flatten())
#model.add(Dense(256, activation='relu'))
#model.add(Dense(num_classes, activation='softmax'))


model.compile(loss=CategoricalCrossentropy(), optimizer='adam',metrics=['accuracy'])

model.build((None,*input_shape))

#print model summary
print(model.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flip (Flip)                 (None, 19, 19, 1)         0
#
#  conv2d_50 (Conv2D)          (None, 19, 19, 16)        160
#
#  conv2d_51 (Conv2D)          (None, 19, 19, 16)        2320
#
#  conv2d_52 (Conv2D)          (None, 19, 19, 32)        4640
#
#  conv2d_53 (Conv2D)          (None, 19, 19, 32)        9248
#
#  conv2d_54 (Conv2D)          (None, 19, 19, 50)        14450
#
#  conv2d_55 (Conv2D)          (None, 19, 19, 128)       57728
#
#  conv2d_56 (Conv2D)          (None, 19, 19, 1)         129
#
#  flatten_10 (Flatten)        (None, 361)               0
#
#  softmax_10 (Softmax)        (None, 361)               0
#
# =================================================================
# Total params: 88,675
# Trainable params: 88,675
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train model

# %%
epochs = 50
batch_size = 128
model.fit(
    generator.generate(batch_size, num_classes),
    steps_per_epoch = generator.get_num_samples()//batch_size,
    epochs = epochs,
    validation_data = test_generator.generate(batch_size, num_classes),
    validation_steps = test_generator.get_num_samples()//batch_size,
    #callbacks=[
    #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
    #] #callback stores model at each epoch
    )
# Out:
# Epoch 1/50
# 329/329 [==============================] - 220s 666ms/step - loss: 4.7108 - accuracy: 0.0838 - val_loss: 4.0611 - val_accuracy: 0.1404
# Epoch 2/50
# 329/329 [==============================] - 211s 642ms/step - loss: 3.9289 - accuracy: 0.1517 - val_loss: 3.8119 - val_accuracy: 0.1671
# Epoch 3/50
# 329/329 [==============================] - 210s 638ms/step - loss: 3.7270 - accuracy: 0.1744 - val_loss: 3.6698 - val_accuracy: 0.1821
# Epoch 4/50
# 329/329 [==============================] - 211s 640ms/step - loss: 3.5798 - accuracy: 0.1948 - val_loss: 3.5433 - val_accuracy: 0.1985
# Epoch 5/50
# 329/329 [==============================] - 204s 621ms/step - loss: 3.4693 - accuracy: 0.2099 - val_loss: 3.4337 - val_accuracy: 0.2125
# Epoch 6/50
# 329/329 [==============================] - 211s 643ms/step - loss: 3.3737 - accuracy: 0.2247 - val_loss: 3.3883 - val_accuracy: 0.2195
# Epoch 7/50
# 329/329 [==============================] - 211s 643ms/step - loss: 3.2909 - accuracy: 0.2382 - val_loss: 3.3484 - val_accuracy: 0.2264
# Epoch 8/50
# 329/329 [==============================] - 219s 665ms/step - loss: 3.2212 - accuracy: 0.2509 - val_loss: 3.2793 - val_accuracy: 0.2382
# Epoch 9/50
# 329/329 [==============================] - 228s 693ms/step - loss: 3.1555 - accuracy: 0.2633 - val_loss: 3.2287 - val_accuracy: 0.2484
# Epoch 10/50
# 329/329 [==============================] - 195s 592ms/step - loss: 3.0984 - accuracy: 0.2742 - val_loss: 3.1743 - val_accuracy: 0.2574
# Epoch 11/50
# 329/329 [==============================] - 196s 597ms/step - loss: 3.0431 - accuracy: 0.2853 - val_loss: 3.1107 - val_accuracy: 0.2667
# Epoch 12/50
# 329/329 [==============================] - 212s 643ms/step - loss: 2.9914 - accuracy: 0.2970 - val_loss: 3.0657 - val_accuracy: 0.2755
# Epoch 13/50
# 329/329 [==============================] - 188s 573ms/step - loss: 2.9490 - accuracy: 0.3075 - val_loss: 3.0351 - val_accuracy: 0.2823
# Epoch 14/50
# 329/329 [==============================] - 192s 584ms/step - loss: 2.9086 - accuracy: 0.3148 - val_loss: 3.0141 - val_accuracy: 0.2872
# Epoch 15/50
# 329/329 [==============================] - 213s 649ms/step - loss: 2.8729 - accuracy: 0.3229 - val_loss: 2.9969 - val_accuracy: 0.2894
# Epoch 16/50
# 329/329 [==============================] - 194s 589ms/step - loss: 2.8247 - accuracy: 0.3341 - val_loss: 2.9666 - val_accuracy: 0.2973
# Epoch 17/50
# 329/329 [==============================] - 211s 643ms/step - loss: 2.7792 - accuracy: 0.3432 - val_loss: 2.9676 - val_accuracy: 0.2977
# Epoch 18/50
# 329/329 [==============================] - 205s 622ms/step - loss: 2.7431 - accuracy: 0.3501 - val_loss: 2.9386 - val_accuracy: 0.3037
# Epoch 19/50
# 329/329 [==============================] - 199s 605ms/step - loss: 2.7065 - accuracy: 0.3588 - val_loss: 2.9034 - val_accuracy: 0.3130
# Epoch 20/50
# 329/329 [==============================] - 193s 588ms/step - loss: 2.6622 - accuracy: 0.3694 - val_loss: 2.8880 - val_accuracy: 0.3177
# Epoch 21/50
# 329/329 [==============================] - 194s 589ms/step - loss: 2.6122 - accuracy: 0.3796 - val_loss: 2.9461 - val_accuracy: 0.3104
# Epoch 22/50
# 329/329 [==============================] - 191s 580ms/step - loss: 2.5665 - accuracy: 0.3871 - val_loss: 2.9702 - val_accuracy: 0.3097
# Epoch 23/50
# 329/329 [==============================] - 188s 572ms/step - loss: 2.5177 - accuracy: 0.3990 - val_loss: 2.9680 - val_accuracy: 0.3101
# Epoch 24/50
# 329/329 [==============================] - 187s 569ms/step - loss: 2.4782 - accuracy: 0.4050 - val_loss: 2.9598 - val_accuracy: 0.3123
# Epoch 25/50
# 329/329 [==============================] - 187s 568ms/step - loss: 2.4474 - accuracy: 0.4115 - val_loss: 2.9019 - val_accuracy: 0.3194
# Epoch 26/50
# 329/329 [==============================] - 189s 574ms/step - loss: 2.4234 - accuracy: 0.4175 - val_loss: 2.8628 - val_accuracy: 0.3264
# Epoch 27/50
# 329/329 [==============================] - 190s 579ms/step - loss: 2.4060 - accuracy: 0.4216 - val_loss: 2.8407 - val_accuracy: 0.3344
# Epoch 28/50
# 329/329 [==============================] - 190s 579ms/step - loss: 2.3904 - accuracy: 0.4251 - val_loss: 2.8428 - val_accuracy: 0.3335
# Epoch 29/50
# 329/329 [==============================] - 188s 573ms/step - loss: 2.3703 - accuracy: 0.4274 - val_loss: 2.8932 - val_accuracy: 0.3305
# Epoch 30/50
# 329/329 [==============================] - 189s 576ms/step - loss: 2.3515 - accuracy: 0.4318 - val_loss: 3.0230 - val_accuracy: 0.3131
# Epoch 31/50
# 329/329 [==============================] - 193s 586ms/step - loss: 2.3174 - accuracy: 0.4412 - val_loss: 2.9649 - val_accuracy: 0.3204
# Epoch 32/50
# 329/329 [==============================] - 188s 573ms/step - loss: 2.2889 - accuracy: 0.4477 - val_loss: 2.8942 - val_accuracy: 0.3284
# Epoch 33/50
# 329/329 [==============================] - 191s 581ms/step - loss: 2.2719 - accuracy: 0.4507 - val_loss: 2.8405 - val_accuracy: 0.3375
# Epoch 34/50
# 329/329 [==============================] - 190s 578ms/step - loss: 2.2554 - accuracy: 0.4513 - val_loss: 2.7755 - val_accuracy: 0.3507
# Epoch 35/50
# 329/329 [==============================] - 191s 582ms/step - loss: 2.2610 - accuracy: 0.4501 - val_loss: 2.8946 - val_accuracy: 0.3297
# Epoch 36/50
# 329/329 [==============================] - 191s 579ms/step - loss: 2.2519 - accuracy: 0.4522 - val_loss: 2.8821 - val_accuracy: 0.3371
# Epoch 37/50
# 329/329 [==============================] - 191s 580ms/step - loss: 2.2346 - accuracy: 0.4543 - val_loss: 2.8082 - val_accuracy: 0.3528
# Epoch 38/50
# 329/329 [==============================] - 186s 565ms/step - loss: 2.1982 - accuracy: 0.4644 - val_loss: 2.8203 - val_accuracy: 0.3546
# Epoch 39/50
# 329/329 [==============================] - 190s 577ms/step - loss: 2.1544 - accuracy: 0.4732 - val_loss: 2.8131 - val_accuracy: 0.3582
# Epoch 40/50
# 329/329 [==============================] - 187s 568ms/step - loss: 2.1138 - accuracy: 0.4814 - val_loss: 2.8083 - val_accuracy: 0.3621
# Epoch 41/50
# 329/329 [==============================] - 229s 695ms/step - loss: 2.0838 - accuracy: 0.4853 - val_loss: 2.8404 - val_accuracy: 0.3623
# Epoch 42/50
# 106/329 [========>.....................] - ETA: 1:52 - loss: 2.1399 - accuracy: 0.4813
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 epochs = 50
#       2 batch_size = 128
# ----> 3 model.fit(
#       4     generator.generate(batch_size, num_classes),
#       5     steps_per_epoch = generator.get_num_samples()//batch_size,
#       6     epochs = epochs,
#       7     validation_data = test_generator.generate(batch_size, num_classes),
#       8     validation_steps = test_generator.get_num_samples()//batch_size,
#       9     #callbacks=[
#      10     #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
#      11     #] #callback stores model at each epoch
#      12     )
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Build ResNet block

# %%
def residual_block(x, filters, kernel_size):
    #Residual path
    conv1 = Conv2D(filters = filters, kernel_size = kernel_size, padding = 'same')(x)
    bn1 = BatchNormalization(axis = -1)(conv1)
    relu1 = Activation('relu')(bn1)
    conv2 = Conv2D(filters = filters, kernel_size = kernel_size, padding = 'same')(relu1)
    residual = BatchNormalization(axis = -1)(conv2)
    
    #add residual to skip connection
    return Activation('relu')(add([x,residual]))

# %% [markdown]
# ## Use Resnet block to enhance previous VGG-type model

# %%
input_shape = (encoder.num_planes, go_board_rows, go_board_cols)

inputs = Input(shape = input_shape) #input is 19x19
res0 = Flip()(inputs)

res1 = residual_block(res0, filters = 16, kernel_size = (3,3))
res2 = residual_block(res1, filters = 16, kernel_size = (3,3))

expand1 = Conv2D(filters = 64, kernel_size = (3,3), activation = 'relu', padding = 'same')(res2)
bottleneck1 = Conv2D(filters = 32, kernel_size = (1,1), activation = 'relu')(res2)

res3 = residual_block(bottleneck1, filters = 32, kernel_size = (3,3))
res4 = residual_block(res3, filters = 32, kernel_size = (3,3))

expand1 = Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu', padding = 'same')(res4)
bottleneck2 = Conv2D(filters = 64, kernel_size = (1,1), activation = 'relu')(res4)


res5 = residual_block(bottleneck2, filters = 64, kernel_size = (3,3))
res6 = residual_block(res5, filters = 64, kernel_size = (3,3))



#obtain prediction
pred1 = Conv2D(filters = 1, kernel_size = (1,1), activation = 'relu')(res6)

prediction = Softmax()(Flatten()(pred1))

model = Model(inputs = inputs, outputs = prediction)

model.compile(loss=CategoricalCrossentropy(), optimizer='adam',metrics=['accuracy'])

model.build((None,*input_shape))

#print model summary
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 1, 19, 19)]  0           []
#
#  flip (Flip)                    (None, 19, 19, 1)    0           ['input_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 19, 19, 16)   160         ['flip[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 19, 19, 16)  64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 19, 19, 16)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 19, 19, 16)   2320        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 19, 19, 16)  64          ['conv2d_40[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 19, 19, 16)   0           ['flip[0][0]',
#                                                                   'batch_normalization_35[0][0]']
#
#  activation_35 (Activation)     (None, 19, 19, 16)   0           ['add_17[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 19, 19, 16)   2320        ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 19, 19, 16)  64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 19, 19, 16)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 19, 19, 16)   2320        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 19, 19, 16)  64          ['conv2d_42[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 19, 19, 16)   0           ['activation_35[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_37 (Activation)     (None, 19, 19, 16)   0           ['add_18[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 19, 19, 32)   544         ['activation_37[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 19, 19, 32)   9248        ['conv2d_44[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 19, 19, 32)  128         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 19, 19, 32)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 19, 19, 32)   9248        ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 19, 19, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 19, 19, 32)   0           ['conv2d_44[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  activation_39 (Activation)     (None, 19, 19, 32)   0           ['add_19[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 19, 19, 32)   9248        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 19, 19, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 19, 19, 32)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 19, 19, 32)   9248        ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 19, 19, 32)  128         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 19, 19, 32)   0           ['activation_39[0][0]',
#                                                                   'batch_normalization_41[0][0]']
#
#  activation_41 (Activation)     (None, 19, 19, 32)   0           ['add_20[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 19, 19, 64)   2112        ['activation_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 19, 19, 64)   36928       ['conv2d_50[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 19, 19, 64)  256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 19, 19, 64)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 19, 19, 64)   36928       ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 19, 19, 64)  256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 19, 19, 64)   0           ['conv2d_50[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  activation_43 (Activation)     (None, 19, 19, 64)   0           ['add_21[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 19, 19, 64)   36928       ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 19, 19, 64)  256         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 19, 19, 64)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 19, 19, 64)   36928       ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 19, 19, 64)  256         ['conv2d_54[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 19, 19, 64)   0           ['activation_43[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  activation_45 (Activation)     (None, 19, 19, 64)   0           ['add_22[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 19, 19, 1)    65          ['activation_45[0][0]']
#
#  flatten_1 (Flatten)            (None, 361)          0           ['conv2d_55[0][0]']
#
#  softmax_1 (Softmax)            (None, 361)          0           ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 196,337
# Trainable params: 195,441
# Non-trainable params: 896
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ### Train deeper Resnet-type model

# %%
epochs = 50
batch_size = 128
model.fit(
    generator.generate(batch_size, num_classes),
    steps_per_epoch = generator.get_num_samples()//batch_size,
    epochs = epochs,
    validation_data = test_generator.generate(batch_size, num_classes),
    validation_steps = test_generator.get_num_samples()//batch_size,
    #callbacks=[
    #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
    #] #callback stores model at each epoch
    )
# Out:
# Epoch 1/50
# 329/329 [==============================] - 437s 1s/step - loss: 4.9447 - accuracy: 0.0737 - val_loss: 4.7674 - val_accuracy: 0.0915
# Epoch 2/50
# 329/329 [==============================] - 512s 2s/step - loss: 3.7270 - accuracy: 0.1729 - val_loss: 3.6492 - val_accuracy: 0.1795
# Epoch 3/50
# 329/329 [==============================] - 401s 1s/step - loss: 3.3917 - accuracy: 0.2216 - val_loss: 3.4601 - val_accuracy: 0.2089
# Epoch 4/50
# 329/329 [==============================] - 390s 1s/step - loss: 3.1864 - accuracy: 0.2561 - val_loss: 3.2672 - val_accuracy: 0.2347
# Epoch 5/50
# 329/329 [==============================] - 388s 1s/step - loss: 3.0127 - accuracy: 0.2865 - val_loss: 3.1283 - val_accuracy: 0.2577
# Epoch 6/50
# 329/329 [==============================] - 389s 1s/step - loss: 2.8576 - accuracy: 0.3164 - val_loss: 3.0679 - val_accuracy: 0.2746
# Epoch 7/50
# 329/329 [==============================] - 387s 1s/step - loss: 2.7068 - accuracy: 0.3502 - val_loss: 3.1089 - val_accuracy: 0.2748
# Epoch 8/50
# 329/329 [==============================] - 391s 1s/step - loss: 2.5691 - accuracy: 0.3773 - val_loss: 2.9632 - val_accuracy: 0.2956
# Epoch 9/50
# 329/329 [==============================] - 393s 1s/step - loss: 2.4322 - accuracy: 0.4070 - val_loss: 2.9874 - val_accuracy: 0.2980
# Epoch 10/50
# 329/329 [==============================] - 388s 1s/step - loss: 2.3124 - accuracy: 0.4337 - val_loss: 3.0276 - val_accuracy: 0.2987
# Epoch 11/50
# 329/329 [==============================] - 395s 1s/step - loss: 2.2100 - accuracy: 0.4542 - val_loss: 2.9482 - val_accuracy: 0.3127
# Epoch 12/50
# 329/329 [==============================] - 391s 1s/step - loss: 2.1039 - accuracy: 0.4743 - val_loss: 3.0302 - val_accuracy: 0.3078
# Epoch 13/50
# 329/329 [==============================] - 394s 1s/step - loss: 2.0155 - accuracy: 0.4897 - val_loss: 3.2940 - val_accuracy: 0.2880
# Epoch 14/50
# 329/329 [==============================] - 389s 1s/step - loss: 1.9164 - accuracy: 0.5103 - val_loss: 3.6332 - val_accuracy: 0.2617
# Epoch 15/50
# 329/329 [==============================] - 388s 1s/step - loss: 1.8532 - accuracy: 0.5197 - val_loss: 3.6019 - val_accuracy: 0.2750
# Epoch 16/50
# 329/329 [==============================] - 387s 1s/step - loss: 1.7873 - accuracy: 0.5335 - val_loss: 3.8582 - val_accuracy: 0.2586
# Epoch 17/50
# 329/329 [==============================] - 389s 1s/step - loss: 1.7190 - accuracy: 0.5484 - val_loss: 3.2388 - val_accuracy: 0.3166
# Epoch 18/50
# 329/329 [==============================] - 392s 1s/step - loss: 1.6426 - accuracy: 0.5658 - val_loss: 3.4725 - val_accuracy: 0.3050
# Epoch 19/50
#  38/329 [==>...........................] - ETA: 5:02 - loss: 1.7279 - accuracy: 0.5498
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 epochs = 50
#       2 batch_size = 128
# ----> 3 model.fit(
#       4     generator.generate(batch_size, num_classes),
#       5     steps_per_epoch = generator.get_num_samples()//batch_size,
#       6     epochs = epochs,
#       7     validation_data = test_generator.generate(batch_size, num_classes),
#       8     validation_steps = test_generator.get_num_samples()//batch_size,
#       9     #callbacks=[
#      10     #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
#      11     #] #callback stores model at each epoch
#      12     )
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Build U-Net-esque network

# %%
input_shape = (encoder.num_planes, go_board_rows, go_board_cols)

inputs = Input(shape = input_shape) #input is 19x19
conv1 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(Flip()(inputs)) 
conv1a = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(conv1)

conv1b = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu')(conv1a) #output is 17x17

conv2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu')(conv1b) #output is 15x15

conv3 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu')(conv2) #output is 13x13

conv4 = Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu')(conv3) #output is 11x11 (Correct size)
conv5 = Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu')(conv4) #output is 9x9

conv6 = Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu')(conv5) #output is 7x7

#rescale 7x7 to 11x11
rescale9x9_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(conv6) #output is 9x9
rescale9x9_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale9x9_1)

rescale11x11_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(rescale9x9_2) #output is 11x11
rescale11x11_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale11x11_1)

#Concat 11x11's together
concat11x11_1 = Concatenate()([rescale11x11_2,conv4])
concat11x11_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(concat11x11_1)

#rescale 11x11 to 15x15
rescale13x13_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(concat11x11_2) #output is 13x13
rescale13x13_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale13x13_1)

rescale15x15_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(rescale13x13_2) #output is 15x15
rescale15x15_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale15x15_1)

#Concat 15x15's together
concat15x15_1 = Concatenate()([rescale15x15_2,conv2])
concat15x15_2 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(concat15x15_1)

#rescale 15x15 to 19x19
rescale17x17_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(concat15x15_2) #output is 17x17
rescale17x17_2 = Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale17x17_1)

rescale19x19_1 = Conv2DTranspose(filters = 16, kernel_size = (3,3), activation = 'relu')(rescale17x17_2) #output is 19x19
rescale19x19_2 = Conv2D(filters = 32, kernel_size = (3,3), activation = 'relu', padding = 'same')(rescale19x19_1)

#Concat 19x19's together
concat19x19_1 = Concatenate()([rescale19x19_2, conv1a])

#Add extra convolutional layers
final_1 = Conv2D(filters = 16, kernel_size = (3,3), activation = 'relu', padding = 'same')(concat19x19_1)
final_2 = Conv2D(filters = 16, kernel_size = (1,1), activation = 'relu')(final_1)
final_3 = Conv2D(filters = 1, kernel_size = (1,1), activation = 'relu')(final_2)

predictions = Softmax()(Flatten()(final_3))

model = Model(inputs = inputs, outputs = predictions)

print(model.summary())

model.compile(loss=CategoricalCrossentropy(), optimizer='adam',metrics=['accuracy'])

model.build((None,*input_shape))
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_54 (InputLayer)          [(None, 1, 19, 19)]  0           []
#
#  flip (Flip)                    (None, 19, 19, 1)    0           ['input_54[0][0]']
#
#  conv2d_467 (Conv2D)            (None, 19, 19, 16)   160         ['flip[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 19, 19, 16)   2320        ['conv2d_467[0][0]']
#
#  conv2d_469 (Conv2D)            (None, 17, 17, 16)   2320        ['conv2d_468[0][0]']
#
#  conv2d_470 (Conv2D)            (None, 15, 15, 16)   2320        ['conv2d_469[0][0]']
#
#  conv2d_471 (Conv2D)            (None, 13, 13, 16)   2320        ['conv2d_470[0][0]']
#
#  conv2d_472 (Conv2D)            (None, 11, 11, 32)   4640        ['conv2d_471[0][0]']
#
#  conv2d_473 (Conv2D)            (None, 9, 9, 32)     9248        ['conv2d_472[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 7, 7, 32)     9248        ['conv2d_473[0][0]']
#
#  conv2d_transpose_100 (Conv2DTr  (None, 9, 9, 16)    4624        ['conv2d_474[0][0]']
#  anspose)
#
#  conv2d_475 (Conv2D)            (None, 9, 9, 16)     2320        ['conv2d_transpose_100[0][0]']
#
#  conv2d_transpose_101 (Conv2DTr  (None, 11, 11, 16)  2320        ['conv2d_475[0][0]']
#  anspose)
#
#  conv2d_476 (Conv2D)            (None, 11, 11, 16)   2320        ['conv2d_transpose_101[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 11, 11, 48)   0           ['conv2d_476[0][0]',
#                                                                   'conv2d_472[0][0]']
#
#  conv2d_477 (Conv2D)            (None, 11, 11, 16)   6928        ['concatenate_48[0][0]']
#
#  conv2d_transpose_102 (Conv2DTr  (None, 13, 13, 16)  2320        ['conv2d_477[0][0]']
#  anspose)
#
#  conv2d_478 (Conv2D)            (None, 13, 13, 16)   2320        ['conv2d_transpose_102[0][0]']
#
#  conv2d_transpose_103 (Conv2DTr  (None, 15, 15, 16)  2320        ['conv2d_478[0][0]']
#  anspose)
#
#  conv2d_479 (Conv2D)            (None, 15, 15, 16)   2320        ['conv2d_transpose_103[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 15, 15, 32)   0           ['conv2d_479[0][0]',
#                                                                   'conv2d_470[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 15, 15, 16)   4624        ['concatenate_49[0][0]']
#
#  conv2d_transpose_104 (Conv2DTr  (None, 17, 17, 16)  2320        ['conv2d_480[0][0]']
#  anspose)
#
#  conv2d_481 (Conv2D)            (None, 17, 17, 32)   4640        ['conv2d_transpose_104[0][0]']
#
#  conv2d_transpose_105 (Conv2DTr  (None, 19, 19, 16)  4624        ['conv2d_481[0][0]']
#  anspose)
#
#  conv2d_482 (Conv2D)            (None, 19, 19, 32)   4640        ['conv2d_transpose_105[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 19, 19, 48)   0           ['conv2d_482[0][0]',
#                                                                   'conv2d_468[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 19, 19, 16)   6928        ['concatenate_50[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 19, 19, 16)   272         ['conv2d_483[0][0]']
#
#  conv2d_485 (Conv2D)            (None, 19, 19, 1)    17          ['conv2d_484[0][0]']
#
#  flatten_36 (Flatten)           (None, 361)          0           ['conv2d_485[0][0]']
#
#  softmax_36 (Softmax)           (None, 361)          0           ['flatten_36[0][0]']
#
# ==================================================================================================
# Total params: 88,433
# Trainable params: 88,433
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ### Train U-net type model

# %%
epochs = 50
batch_size = 128
model.fit(
    generator.generate(batch_size, num_classes),
    steps_per_epoch = generator.get_num_samples()//batch_size,
    epochs = epochs,
    validation_data = test_generator.generate(batch_size, num_classes),
    validation_steps = test_generator.get_num_samples()//batch_size,
    #callbacks=[
    #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
    #] #callback stores model at each epoch
    )
# Out:
# Epoch 1/50
# 329/329 [==============================] - 186s 560ms/step - loss: 4.9081 - accuracy: 0.0634 - val_loss: 4.0826 - val_accuracy: 0.1214
# Epoch 2/50
# 329/329 [==============================] - 169s 516ms/step - loss: 3.9704 - accuracy: 0.1353 - val_loss: 3.8611 - val_accuracy: 0.1492
# Epoch 3/50
# 329/329 [==============================] - 168s 511ms/step - loss: 3.8095 - accuracy: 0.1556 - val_loss: 3.7653 - val_accuracy: 0.1588
# Epoch 4/50
# 329/329 [==============================] - 149s 453ms/step - loss: 3.7058 - accuracy: 0.1685 - val_loss: 3.6604 - val_accuracy: 0.1706
# Epoch 5/50
# 329/329 [==============================] - 149s 454ms/step - loss: 3.6228 - accuracy: 0.1789 - val_loss: 3.6001 - val_accuracy: 0.1779
# Epoch 6/50
# 329/329 [==============================] - 148s 451ms/step - loss: 3.5521 - accuracy: 0.1880 - val_loss: 3.5820 - val_accuracy: 0.1802
# Epoch 7/50
# 329/329 [==============================] - 152s 461ms/step - loss: 3.4905 - accuracy: 0.1951 - val_loss: 3.5429 - val_accuracy: 0.1875
# Epoch 8/50
# 329/329 [==============================] - 202s 613ms/step - loss: 3.4359 - accuracy: 0.2052 - val_loss: 3.4866 - val_accuracy: 0.1945
# Epoch 9/50
# 329/329 [==============================] - 197s 599ms/step - loss: 3.3938 - accuracy: 0.2131 - val_loss: 3.4450 - val_accuracy: 0.2012
# Epoch 10/50
# 329/329 [==============================] - 160s 488ms/step - loss: 3.3412 - accuracy: 0.2197 - val_loss: 3.3957 - val_accuracy: 0.2098
# Epoch 11/50
# 329/329 [==============================] - 166s 505ms/step - loss: 3.2902 - accuracy: 0.2296 - val_loss: 3.3629 - val_accuracy: 0.2180
# Epoch 12/50
# 329/329 [==============================] - 188s 573ms/step - loss: 3.2461 - accuracy: 0.2383 - val_loss: 3.3288 - val_accuracy: 0.2223
# Epoch 13/50
#  45/329 [===>..........................] - ETA: 1:56 - loss: 3.3022 - accuracy: 0.2339
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 3
#       1 epochs = 50
#       2 batch_size = 128
# ----> 3 model.fit(
#       4     generator.generate(batch_size, num_classes),
#       5     steps_per_epoch = generator.get_num_samples()//batch_size,
#       6     epochs = epochs,
#       7     validation_data = test_generator.generate(batch_size, num_classes),
#       8     validation_steps = test_generator.get_num_samples()//batch_size,
#       9     #callbacks=[
#      10     #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
#      11     #] #callback stores model at each epoch
#      12     )
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## P4-equivariant VGG-type CNN

# %%
#define keras model
input_shape = (encoder.num_planes, go_board_rows, go_board_cols)

model = Sequential()
model.add(Input(shape=input_shape))
model.add(Flip())

#small_layers = small.layers(input_shape)
#for layer in small_layers:
#    model.add(layer)

#group convolution

#three 3x3 convs has a receptive field equivalent to one 7x7
model.add(P4Conv2D(num_channels = 8, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(P4Conv2D(num_channels = 8, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(P4Conv2D(num_channels = 8, kernel_size = (3, 3),activation='relu',padding = 'same'))

#model.add(P4Conv2D(num_channels = 6, kernel_size = (1, 1),activation='relu'))


#two 3x3 convs has a receptive field equivalent to one 5x5
model.add(P4Conv2D(num_channels = 16, kernel_size = (3, 3),activation='relu',padding = 'same'))
model.add(P4Conv2D(num_channels = 16, kernel_size = (3, 3),activation='relu',padding = 'same'))

#bottleneck to reduce parameters
#model.add(P4Conv2D(num_channels = 8, kernel_size = (1, 1),activation='relu'))


#two 3x3 convs has a receptive field equivalent to one 5x5
#model.add(P4Conv2D(num_channels = 32, kernel_size = (3, 3),activation='relu',padding = 'same'))
#model.add(P4Conv2D(num_channels = 32, kernel_size = (3, 3),activation='relu',padding = 'same'))

#bottleneck to reduce parameters
#model.add(P4Conv2D(num_channels = 8, kernel_size = (1, 1),activation='relu'))


#two 3x3 convs has a receptive field equivalent to one 5x5
#model.add(P4Conv2D(num_channels = 64, kernel_size = (3, 3),activation='relu',padding = 'same'))
#model.add(P4Conv2D(num_channels = 64, kernel_size = (3, 3),activation='relu',padding = 'same'))

#bottleneck to reduce parameters
#model.add(P4Conv2D(num_channels = 8, kernel_size = (1, 1),activation='relu'))

#switch feature volume from being a function of the space group to the translation subgroup
model.add(Conv2D(filters = 128, kernel_size = (3,3), activation = 'relu',padding='same'))

#obtain prediction
model.add(Conv2D(filters = 1, kernel_size = (1,1), activation = 'relu'))

model.add(Flatten())
model.add(Softmax())

#model.add(Dense(100, activation='relu'))
#model.add(Dense(num_classes, activation='softmax'))



model.compile(loss=CategoricalCrossentropy(), optimizer='adam',metrics=['accuracy'])

model.build((None,*input_shape))

#print model summary
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flip (Flip)                 (None, 19, 19, 1)         0
#
#  p4_conv2d_27 (P4Conv2D)     (None, 19, 19, 32)        72
#
#  p4_conv2d_28 (P4Conv2D)     (None, 19, 19, 32)        2304
#
#  p4_conv2d_29 (P4Conv2D)     (None, 19, 19, 32)        2304
#
#  p4_conv2d_30 (P4Conv2D)     (None, 19, 19, 64)        4608
#
#  p4_conv2d_31 (P4Conv2D)     (None, 19, 19, 64)        9216
#
#  conv2d_6 (Conv2D)           (None, 19, 19, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 19, 19, 1)         129
#
#  flatten_3 (Flatten)         (None, 361)               0
#
#  softmax_3 (Softmax)         (None, 361)               0
#
# =================================================================
# Total params: 92,489
# Trainable params: 92,489
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train model

# %%
epochs = 50
batch_size = 128
model.fit(
    generator.generate(batch_size, num_classes),
    steps_per_epoch = generator.get_num_samples()//batch_size,
    epochs = epochs,
    validation_data = test_generator.generate(batch_size, num_classes),
    validation_steps = test_generator.get_num_samples()//batch_size,
    #callbacks=[
    #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
    #] #callback stores model at each epoch
    )
# Out:
# Epoch 1/50
# 2023-01-21 15:11:02.096660: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: sequential_3/p4_conv2d_30/rot90_2/Assert/AssertGuard/branch_executed/_274
# 329/329 [==============================] - ETA: 0s - loss: 4.8846 - accuracy: 0.0635
# 2023-01-21 15:14:47.827071: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: sequential_3/p4_conv2d_27/rot90/Assert/AssertGuard/branch_executed/_8
# 329/329 [==============================] - 311s 926ms/step - loss: 4.8846 - accuracy: 0.0635 - val_loss: 4.3507 - val_accuracy: 0.0983
# Epoch 2/50
# 329/329 [==============================] - 315s 958ms/step - loss: 4.2174 - accuracy: 0.1136 - val_loss: 4.1885 - val_accuracy: 0.1159
# Epoch 3/50
# 329/329 [==============================] - 303s 921ms/step - loss: 4.0545 - accuracy: 0.1321 - val_loss: 4.1153 - val_accuracy: 0.1263
# Epoch 4/50
# 329/329 [==============================] - 291s 887ms/step - loss: 3.9662 - accuracy: 0.1424 - val_loss: 3.9884 - val_accuracy: 0.1401
# Epoch 5/50
# 329/329 [==============================] - 266s 810ms/step - loss: 3.8990 - accuracy: 0.1526 - val_loss: 3.9251 - val_accuracy: 0.1460
# Epoch 6/50
# 329/329 [==============================] - 276s 840ms/step - loss: 3.8495 - accuracy: 0.1577 - val_loss: 3.8809 - val_accuracy: 0.1501
# Epoch 7/50
# 329/329 [==============================] - 274s 833ms/step - loss: 3.8098 - accuracy: 0.1629 - val_loss: 3.8549 - val_accuracy: 0.1529
# Epoch 8/50
# 329/329 [==============================] - 268s 815ms/step - loss: 3.7736 - accuracy: 0.1683 - val_loss: 3.8178 - val_accuracy: 0.1590
# Epoch 9/50
# 329/329 [==============================] - 272s 827ms/step - loss: 3.7429 - accuracy: 0.1729 - val_loss: 3.7833 - val_accuracy: 0.1621
# Epoch 10/50
# 329/329 [==============================] - 275s 836ms/step - loss: 3.7146 - accuracy: 0.1772 - val_loss: 3.7746 - val_accuracy: 0.1645
# Epoch 11/50
# 329/329 [==============================] - 275s 836ms/step - loss: 3.6908 - accuracy: 0.1819 - val_loss: 3.7528 - val_accuracy: 0.1669
# Epoch 12/50
# 329/329 [==============================] - 278s 845ms/step - loss: 3.6682 - accuracy: 0.1868 - val_loss: 3.7399 - val_accuracy: 0.1705
# Epoch 13/50
# 329/329 [==============================] - 284s 864ms/step - loss: 3.6444 - accuracy: 0.1896 - val_loss: 3.7230 - val_accuracy: 0.1739
# Epoch 14/50
# 329/329 [==============================] - 279s 848ms/step - loss: 3.6222 - accuracy: 0.1923 - val_loss: 3.6900 - val_accuracy: 0.1780
# Epoch 15/50
# 329/329 [==============================] - 282s 859ms/step - loss: 3.5986 - accuracy: 0.1972 - val_loss: 3.6518 - val_accuracy: 0.1821
# Epoch 16/50
# 329/329 [==============================] - 279s 848ms/step - loss: 3.5771 - accuracy: 0.2000 - val_loss: 3.6310 - val_accuracy: 0.1871
# Epoch 17/50
# 329/329 [==============================] - 277s 842ms/step - loss: 3.5618 - accuracy: 0.2030 - val_loss: 3.6368 - val_accuracy: 0.1859
# Epoch 18/50
# 329/329 [==============================] - 277s 844ms/step - loss: 3.5431 - accuracy: 0.2042 - val_loss: 3.6207 - val_accuracy: 0.1897
# Epoch 19/50
# 317/329 [===========================>..] - ETA: 7s - loss: 3.5182 - accuracy: 0.2086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 epochs = 50
#       2 batch_size = 128
# ----> 3 model.fit(
#       4     generator.generate(batch_size, num_classes),
#       5     steps_per_epoch = generator.get_num_samples()//batch_size,
#       6     epochs = epochs,
#       7     validation_data = test_generator.generate(batch_size, num_classes),
#       8     validation_steps = test_generator.get_num_samples()//batch_size,
#       9     #callbacks=[
#      10     #ModelCheckpoint('checkpoints/small_model_epoch_{epoch}.h5')
#      11     #] #callback stores model at each epoch
#      12     )
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/data_sci/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
